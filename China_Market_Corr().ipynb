# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# xls = pd.ExcelFile('/content/Months data.xlsx')
# df1 = pd.read_excel(xls, 'stringency_index Avg')
# df2 = pd.read_excel(xls, 'government_response_index Avg')
# df3 = pd.read_excel(xls, 'containment_health_index Avg')
# df4 = pd.read_excel(xls, 'economic_support_index avg')
# df5 = pd.read_excel(xls, 'Stock market returns')
# df6 = pd.read_excel(xls, 'confirmed_deaths')
# df7 = pd.read_excel(xls, 'confirmed_cases ')

# df7.head(13)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/China.csv")

df.head()
# Out:
#   Month  SZSE Component Price return  ...  confirmed_deaths  confirmed_cases
# 0   Jan                         0.43  ...               889             37897
# 1   Feb                         0.22  ...             46380           1631535
# 2   Mar                         0.01  ...             98383           2506848
# 3   Apr                         0.11  ...            118170           2469365
# 4   May                         0.20  ...            143639           2571194
#
# [5 rows x 8 columns]

# %%
df.corr()
# Out:
#                                SZSE Component Price return  ...  confirmed_cases
# SZSE Component Price return                       1.000000  ...         -0.110373
# stringency_index Avg                             -0.206965  ...          0.804884
# government_response_index Avg                     0.014987  ...          0.887943
# containment_health_index Avg                     -0.146974  ...          0.867079
# economic_support_index avg                        0.631739  ...          0.574530
# confirmed_deaths                                  0.142974  ...          0.940296
# confirmed_cases                                  -0.110373  ...          1.000000
#
# [7 rows x 7 columns]

# %%
sns.heatmap(df.corr());

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')

# %%
plt.savefig('save_as_a_png.png')
